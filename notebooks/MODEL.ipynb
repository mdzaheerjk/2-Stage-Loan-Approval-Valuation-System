# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
# %matplotlib inline

# %%
data_path=Path("../data/loan_approval_dataset.csv")
print("Dataset Exists : ",data_path.exists())
# Out:
# Dataset Exists :  True

# %%
df=pd.read_csv(data_path)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.columns.to_list()
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' education',
#  ' self_employed',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' loan_status']

# %%
df.columns=df.columns.str.strip()

# %%
df.columns.to_list()
# Out:
# ['loan_id',
#  'no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.describe(include='all')
# Out:
#             loan_id  no_of_dependents  education self_employed  income_annum  \
# count   4269.000000       4269.000000       4269          4269  4.269000e+03
# unique          NaN               NaN          2             2           NaN
# top             NaN               NaN   Graduate           Yes           NaN
# freq            NaN               NaN       2144          2150           NaN
# mean    2135.000000          2.498712        NaN           NaN  5.059124e+06
# std     1232.498479          1.695910        NaN           NaN  2.806840e+06
# min        1.000000          0.000000        NaN           NaN  2.000000e+05
# 25%     1068.000000          1.000000        NaN           NaN  2.700000e+06
# 50%     2135.000000          3.000000        NaN           NaN  5.100000e+06
# 75%     3202.000000          4.000000        NaN           NaN  7.500000e+06
# max     4269.000000          5.000000        NaN           NaN  9.900000e+06
#
#          loan_amount    loan_term  cibil_score  residential_assets_value  \
# count   4.269000e+03  4269.000000  4269.000000              4.269000e+03
# unique           NaN          NaN          NaN                       NaN
# top              NaN          NaN          NaN                       NaN
# freq             NaN          NaN          NaN                       NaN
# mean    1.513345e+07    10.900445   599.936051              7.472617e+06
# std     9.043363e+06     5.709187   172.430401              6.503637e+06
# min     3.000000e+05     2.000000   300.000000             -1.000000e+05
# 25%     7.700000e+06     6.000000   453.000000              2.200000e+06
# 50%     1.450000e+07    10.000000   600.000000              5.600000e+06
# 75%     2.150000e+07    16.000000   748.000000              1.130000e+07
# max     3.950000e+07    20.000000   900.000000              2.910000e+07
#
#         commercial_assets_value  luxury_assets_value  bank_asset_value  \
# count              4.269000e+03         4.269000e+03      4.269000e+03
# unique                      NaN                  NaN               NaN
# top                         NaN                  NaN               NaN
# freq                        NaN                  NaN               NaN
# mean               4.973155e+06         1.512631e+07      4.976692e+06
# std                4.388966e+06         9.103754e+06      3.250185e+06
# min                0.000000e+00         3.000000e+05      0.000000e+00
# 25%                1.300000e+06         7.500000e+06      2.300000e+06
# 50%                3.700000e+06         1.460000e+07      4.600000e+06
# 75%                7.600000e+06         2.170000e+07      7.100000e+06
# max                1.940000e+07         3.920000e+07      1.470000e+07
#
#        loan_status
# count         4269
# unique           2
# top       Approved
# freq          2656
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# # EDA

# %%
df.columns.tolist()
# Out:
# ['loan_id',
#  'no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
target_col='loan_status'

# %%
print("using Target Column : ",target_col)
display(df[target_col].value_counts(dropna=False))
sns.countplot(x=target_col,data=df)
plt.title("Target Distribution")
plt.show()
# Out:
# using Target Column :  loan_status
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df=df.drop(columns=['loan_id'],errors='ignore')

# %%
df.head(1)
# Out:
#    no_of_dependents  education self_employed  income_annum  loan_amount  \
# 0                 2   Graduate            No       9600000     29900000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
#
#    luxury_assets_value  bank_asset_value loan_status
# 0             22700000           8000000    Approved

# %%
df_clf=df.dropna(subset=[target_col]).copy()

# %%
x=df_clf.drop(columns=[target_col])
y=df_clf[target_col].copy()

# %%
x.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value
# 0             22700000           8000000
# 1              8800000           3300000
# 2             33300000          12800000
# 3             23300000           7900000
# 4             29400000           5000000

# %%
y.head()
# Out:
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected
# Name: loan_status, dtype: object

# %% [markdown]
# # Feature Types

# %%
cat_cols=x.select_dtypes(include=['object','category']).columns.to_list()
num_cols=x.select_dtypes(include=[np.number]).columns.to_list()

# %%
print("Categorical Colums : ",cat_cols)
print("Numerical Columns : ",num_cols)
# Out:
# Categorical Colums :  ['education', 'self_employed']
# Numerical Columns :  ['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']

# %% [markdown]
# # preprocessing pipeline

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
numerical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
])

# %%
categorical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor=ColumnTransformer(transformers=[
    ('num',numerical_transformer,num_cols),
    ('cat',categorical_transformer,cat_cols)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['no_of_dependents', 'income_annum',
#                                   'loan_amount', 'loan_term', 'cibil_score',
#                                   'residential_assets_value',
#                                   'commercial_assets_value',
#                                   'luxury_assets_value', 'bank_asset_value']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['education', 'self_employed'])])

# %% [markdown]
# # Stage - 1 Classification baseline

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
x.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value
# 0             22700000           8000000
# 1              8800000           3300000
# 2             33300000          12800000
# 3             23300000           7900000
# 4             29400000           5000000

# %%
y.head()
# Out:
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected
# Name: loan_status, dtype: object

# %%
unique_vals=sorted(y.unique())
unique_vals
# Out:
# [' Approved', ' Rejected']

# %%
y=df_clf[target_col].astype(str).str.strip().str.lower()

# %%
unique_vals=sorted(y.unique())
unique_vals
# Out:
# ['approved', 'rejected']

# %%
y=(y=='approved').astype(int)

# %%
unique_vals=sorted(y.unique())
unique_vals
# Out:
# [0, 1]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: loan_status, dtype: int32

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print("Train Size : ",x_train.shape)
print("Test Size : ",x_test.shape)
# Out:
# Train Size :  (3415, 11)
# Test Size :  (854, 11)

# %% [markdown]
# # Fit RF baseline pipelines

# %%
rf_clf_pipeline=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('rf_clf',RandomForestClassifier())
])

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    'rf_clf__n_estimators' : [100,200,300,400],
    'rf_clf__max_depth' : [None, 4, 8, 10],
    'rf_clf__max_features' : ['sqrt', None]
}
grid=GridSearchCV(rf_clf_pipeline,param_grid,cv=5,scoring='f1',n_jobs=-1)
grid.fit(x_train,y_train)
print("Best Params (rf_cls) : ",grid.best_params_)
best_clf=grid.best_estimator_
y_pred_best=best_clf.predict(x_test)

print("classification Report is :\n ",classification_report(y_test,y_pred_best))
# Out:
# Best Params (rf_cls) :  {'rf_clf__max_depth': None, 'rf_clf__max_features': None, 'rf_clf__n_estimators': 400}
# classification Report is :
#                 precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       318
#            1       0.98      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854

# %%
rf_clf_pipeline=Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('rf_clf',RandomForestClassifier(max_depth=None,max_features=None,n_estimators=400,random_state=42,oob_score=True))
])
rf_clf_pipeline.fit(x_train,y_train)
y_pred_cls=rf_clf_pipeline.predict(x_test)
print(classification_report(y_test,y_pred_cls))
print("Rf cls OOB Score is : ",getattr(rf_clf_pipeline.named_steps['rf_clf'],'oob_score_',None))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       318
#            1       0.98      0.99      0.99       536
#
#     accuracy                           0.98       854
#    macro avg       0.98      0.98      0.98       854
# weighted avg       0.98      0.98      0.98       854
#
# Rf cls OOB Score is :  0.983601756954612

# %%
rf_clf_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['no_of_dependents',
#                                                    'income_annum',
#                                                    'loan_amount', 'loan_term',
#                                                    'cibil_score',
#                                                    'residential_assets_value',
#                                                    'commercial_assets_value',
#                                                    'luxury_assets_value',
#                                                    'bank_asset_value']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['education',
#                                                    'self_employed'])])),
#                 ('rf_clf',
#                  RandomForestClassifier(max_features=None, n_estimators=400,
#                                         oob_score=True, random_state=42))])

# %% [markdown]
# # checking feature importance

# %%
feature_importance=rf_clf_pipeline.named_steps['rf_clf'].feature_importances_
preprocessor=rf_clf_pipeline.named_steps['preprocessor']
featues_names=preprocessor.get_feature_names_out()

importance_df=pd.DataFrame(
    {
        'Feature':featues_names,
        'Importance':feature_importance
    }
)

importance_df=importance_df.sort_values(by='Importance',ascending=False)
print("Top 10 Importance Features :\n",importance_df.head(10))

plt.figure(figsize=(10,6))
plt.barh(importance_df['Feature'][:10],importance_df['Importance'][:10])
plt.xlabel("Random Forest Feature Importance")
plt.ylabel("Feature")
plt.title("Top 10 Importance Featutures ")
plt.show()
# Out:
# Top 10 Importance Features :
#                            Feature  Importance
# 4                num__cibil_score    0.827222
# 3                  num__loan_term    0.079855
# 2                num__loan_amount    0.033071
# 1               num__income_annum    0.026240
# 7        num__luxury_assets_value    0.008096
# 5   num__residential_assets_value    0.007476
# 6    num__commercial_assets_value    0.006297
# 8           num__bank_asset_value    0.005134
# 0           num__no_of_dependents    0.004316
# 11         cat__self_employed_ No    0.000797

# %% [markdown]
# # Stage 2 : regression

# %%
df['loan_status'].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df['loan_status']=df['loan_status'].str.strip()

# %%
df['loan_status'].unique()
# Out:
# array(['Approved', 'Rejected'], dtype=object)

# %%
approved_df=df[df['loan_status']=='Approved'].copy()

# %%
approved_df.shape
# Out:
# (2656, 12)

# %%
approved_df.head()
# Out:
#     no_of_dependents  education self_employed  income_annum  loan_amount  \
# 0                  2   Graduate            No       9600000     29900000
# 6                  5   Graduate            No       8700000     33000000
# 8                  0   Graduate           Yes        800000      2200000
# 10                 4   Graduate           Yes       2900000     11200000
# 13                 2   Graduate           Yes       9100000     31500000
#
#     loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0          12          778                   2400000                 17600000
# 6           4          678                  22500000                 14800000
# 8          20          782                   1300000                   800000
# 10          2          547                   8100000                  4700000
# 13         14          679                  10800000                 16600000
#
#     luxury_assets_value  bank_asset_value loan_status
# 0              22700000           8000000    Approved
# 6              29200000           4300000    Approved
# 8               2800000            600000    Approved
# 10              9500000           3100000    Approved
# 13             20900000           5000000    Approved

# %%
reg_target='loan_amount'
reg_df=approved_df.dropna(subset=[reg_target]).copy()

# %%
x_reg=reg_df.drop(columns=[reg_target])
y_reg=reg_df[reg_target]

# %%
cat_cols_reg=x_reg.select_dtypes(include=['object','category']).columns.to_list()
num_cols_reg=x_reg.select_dtypes(include=[np.number]).columns.to_list()

# %%
print("Categorical Columns : ",cat_cols_reg)
print("Numerical Columns : ",num_cols_reg)
# Out:
# Categorical Columns :  ['education', 'self_employed', 'loan_status']
# Numerical Columns :  ['no_of_dependents', 'income_annum', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']

# %%
xr_train,xr_test,yr_train,yr_test=train_test_split(x_reg,y_reg,test_size=0.2,random_state=42)
print("Train Size : ",xr_train.shape)
print("Test size",xr_test.shape)
# Out:
# Train Size :  (2124, 11)
# Test size (532, 11)

# %%
reg_preprocessor=ColumnTransformer(transformers=[
    ('num',numerical_transformer,num_cols_reg),
    ('cat',categorical_transformer,cat_cols_reg)
],remainder='drop')

# %% [markdown]
# # Fit RF_reg baseline model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg_pipeline=Pipeline(steps=[
    ('preprocessor',reg_preprocessor),
    ('rf_reg',RandomForestRegressor())
])

# %%
param_reg_grid={
    'rf_reg__n_estimators' : [100,200,300,400],
    'rf_reg__max_depth' : [None, 4, 8, 10],
    'rf_reg__max_features' : ['sqrt', None],
    'rf_reg__min_samples_split' : [2,5,10]
}

# %%
grid=GridSearchCV(rf_reg_pipeline,param_reg_grid,cv=5,scoring='r2',n_jobs=-1)
grid.fit(xr_train,yr_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['no_of_dependents',
#                                                                           'income_annum',
#                                                                           'loan_term',
#                                                                           'cibil_score',
#                                                                           'residential_assets_value',
#                                                                           'commercial_assets_value',
#                                                                           'luxury_assets_value',
#                                                                           'bank_asset_value']),
#                                                                         ('c...
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['education',
#                                                                           'self_employed',
#                                                                           'loan_status'])])),
#                                        ('rf_reg', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'rf_reg__max_depth': [None, 4, 8, 10],
#                          'rf_reg__max_features': ['sqrt', None],
#                          'rf_reg__min_samples_split': [2, 5, 10],
#                          'rf_reg__n_estimators': [100, 200, 300, 400]},
#              scoring='r2')

# %%
print("Best Params (rf_reg) : ",grid.best_params_)
best_reg=grid.best_estimator_
# Out:
# Best Params (rf_reg) :  {'rf_reg__max_depth': 4, 'rf_reg__max_features': None, 'rf_reg__min_samples_split': 10, 'rf_reg__n_estimators': 300}

# %%
grid.best_score_
# Out:
# 0.867221501257004

# %% [markdown]
# # regression validation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
rf_reg_pipeline=Pipeline(steps=[
    ('preprocessor',reg_preprocessor),
    ('rf_reg',RandomForestRegressor(
        max_depth=8,
        max_features=None,
        min_samples_split=5,
        n_estimators=200,
        random_state=10
    ))
])
rf_reg_pipeline.fit(xr_train,yr_train)
yr_test_pred=rf_reg_pipeline.predict(xr_test)
print("MSE : ",mean_squared_error(yr_test,yr_test_pred))
print("MAE : ",mean_absolute_error(yr_test,yr_test_pred))
print("R2 : ",r2_score(yr_test,yr_test_pred))
# Out:
# MSE :  10978004899091.88
# MAE :  2461700.815495691
# R2 :  0.8722769982157768

# %% [markdown]
# # checking feature importance

# %%
feature_importance=rf_reg_pipeline.named_steps['rf_reg'].feature_importances_
preprocessor=rf_reg_pipeline.named_steps['preprocessor']
featues_names=preprocessor.get_feature_names_out()

importance_df=pd.DataFrame(
    {
        'Feature':featues_names,
        'Importance':feature_importance
    }
)
importance_df=importance_df.sort_values(by='Importance',ascending=False)

print("TOP 10 Important Features : \n",importance_df.head(10))

plt.figure(figsize=(10,6))
plt.barh(importance_df['Feature'][:10],importance_df['Importance'][:10])
plt.xlabel("Random forest feature importance")
plt.ylabel("Feature")
# Out:
# TOP 10 Important Features :
#                            Feature  Importance
# 1               num__income_annum    0.935109
# 3                num__cibil_score    0.012736
# 5    num__commercial_assets_value    0.010954
# 6        num__luxury_assets_value    0.010305
# 7           num__bank_asset_value    0.009560
# 4   num__residential_assets_value    0.009514
# 2                  num__loan_term    0.006028
# 0           num__no_of_dependents    0.004044
# 10         cat__self_employed_ No    0.000503
# 8        cat__education_ Graduate    0.000436
# Text(0, 0.5, 'Feature')

# %% [markdown]
# # Save Artifacts and combine them in a prediction function

# %%
import joblib

# %%
joblib.dump(rf_clf_pipeline,'../models/stage_1_rf_classifier_pipeline.pkl')
joblib.dump(rf_reg_pipeline,'../models/stage_2_rf_regression_pipeline.pkl')
# Out:
# ['../models/stage_2_rf_regression_pipeline.pkl']
