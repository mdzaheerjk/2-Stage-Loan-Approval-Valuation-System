# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,mean_absolute_error,mean_squared_error,r2_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.model_selection import GridSearchCV
import warnings
import joblib

# %%
warnings.filterwarnings('ignore')

# %%
data_path=Path('./loan_approval_dataset.csv')
print("Data set is exist : ",data_path.exists())
# Out:
# Data set is exist :  True

# %%
df=pd.read_csv(data_path)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.columns.to_list()
# Out:
# ['loan_id',
#  ' no_of_dependents',
#  ' education',
#  ' self_employed',
#  ' income_annum',
#  ' loan_amount',
#  ' loan_term',
#  ' cibil_score',
#  ' residential_assets_value',
#  ' commercial_assets_value',
#  ' luxury_assets_value',
#  ' bank_asset_value',
#  ' loan_status']

# %%
df.columns=df.columns.str.strip()

# %%
df.columns.to_list()
# Out:
# ['loan_id',
#  'no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
df.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   loan_id                   4269 non-null   int64
#  1   no_of_dependents          4269 non-null   int64
#  2   education                 4269 non-null   object
#  3   self_employed             4269 non-null   object
#  4   income_annum              4269 non-null   int64
#  5   loan_amount               4269 non-null   int64
#  6   loan_term                 4269 non-null   int64
#  7   cibil_score               4269 non-null   int64
#  8   residential_assets_value  4269 non-null   int64
#  9   commercial_assets_value   4269 non-null   int64
#  10  luxury_assets_value       4269 non-null   int64
#  11  bank_asset_value          4269 non-null   int64
#  12  loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.describe(include='all')
# Out:
#             loan_id  no_of_dependents  education self_employed  income_annum  \
# count   4269.000000       4269.000000       4269          4269  4.269000e+03
# unique          NaN               NaN          2             2           NaN
# top             NaN               NaN   Graduate           Yes           NaN
# freq            NaN               NaN       2144          2150           NaN
# mean    2135.000000          2.498712        NaN           NaN  5.059124e+06
# std     1232.498479          1.695910        NaN           NaN  2.806840e+06
# min        1.000000          0.000000        NaN           NaN  2.000000e+05
# 25%     1068.000000          1.000000        NaN           NaN  2.700000e+06
# 50%     2135.000000          3.000000        NaN           NaN  5.100000e+06
# 75%     3202.000000          4.000000        NaN           NaN  7.500000e+06
# max     4269.000000          5.000000        NaN           NaN  9.900000e+06
#
# ...

# %%
df.columns.to_list()
# Out:
# ['loan_id',
#  'no_of_dependents',
#  'education',
#  'self_employed',
#  'income_annum',
#  'loan_amount',
#  'loan_term',
#  'cibil_score',
#  'residential_assets_value',
#  'commercial_assets_value',
#  'luxury_assets_value',
#  'bank_asset_value',
#  'loan_status']

# %%
target_column='loan_status'

# %%
print("using Target Column is :",target_column)
print(df[target_column].value_counts())
df[target_column].value_counts().plot(kind='bar')
plt.title("Target Distribution")
plt.show()
# Out:
# using Target Column is : loan_status
# loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df=df.drop(columns=['loan_id'],errors='ignore')

# %%
df.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
# ...

# %%
df_clf=df.copy()

# %%
x=df_clf.drop(columns=[target_column])
y=df_clf[target_column].copy()

# %%
x.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value
# ...

# %%
y.head()
# Out:
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected
# Name: loan_status, dtype: object

# %% [markdown]
# # Feature Types

# %%
cat_column=x.select_dtypes(include=['object','category']).columns.to_list()
num_column=x.select_dtypes(include=[np.number]).columns.to_list()

# %%
print("Categorical Features Are : ", cat_column)
print("numerical Columns Are : ",num_column)
# Out:
# Categorical Features Are :  ['education', 'self_employed']
# numerical Columns Are :  ['no_of_dependents', 'income_annum', 'loan_amount', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']

# %% [markdown]
# ## Preprocessing Pipeline

# %%
numeric_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
])

# %%
categorical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
   ('encoding',OneHotEncoder(handle_unknown='ignore')) 
]
)

# %%
preprocessor=ColumnTransformer(transformers=[
    ('num',numeric_transformer,num_column),
    ('cat',categorical_transformer,cat_column)
],remainder='drop')

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['no_of_dependents', 'income_annum',
#                                   'loan_amount', 'loan_term', 'cibil_score',
#                                   'residential_assets_value',
#                                   'commercial_assets_value',
#                                   'luxury_assets_value', 'bank_asset_value']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoding',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
# ...

# %%
x.head()
# Out:
#    no_of_dependents      education self_employed  income_annum  loan_amount  \
# 0                 2       Graduate            No       9600000     29900000
# 1                 0   Not Graduate           Yes       4100000     12200000
# 2                 3       Graduate            No       9100000     29700000
# 3                 3       Graduate            No       8200000     30700000
# 4                 5   Not Graduate           Yes       9800000     24200000
#
#    loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0         12          778                   2400000                 17600000
# 1          8          417                   2700000                  2200000
# 2         20          506                   7100000                  4500000
# 3          8          467                  18200000                  3300000
# 4         20          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value
# ...

# %%
y.head()
# Out:
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected
# Name: loan_status, dtype: object

# %%
unique_values=sorted(y.unique())
unique_values
# Out:
# [' Approved', ' Rejected']

# %%
y=df_clf[target_column].str.strip().str.lower()

# %%
unique_values=sorted(y.unique())
unique_values
# Out:
# ['approved', 'rejected']

# %%
y=y.str.strip().str.lower().map({'approved':1, 'rejected':0})

# %%
unique_values=sorted(y.unique())
unique_values
# Out:
# [np.int64(0), np.int64(1)]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    0
# Name: loan_status, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)
print("X train shape is :",x_train.shape)
print("X test size is : ",x_test.shape)
# Out:
# X train shape is : (3415, 11)
# X test size is :  (854, 11)

# %%
rf_cls_pipeline=Pipeline(steps=[
    ('preprocess',preprocessor),
    ('rf_clf',RandomForestClassifier())
])

# %%
param_grid={
    'rf_clf__n_estimators':[100,200,300,400],
    'rf_clf__max_depth':[None,4,8,10],
    'rf_clf__max_features':['sqrt',None]
}
grid=GridSearchCV(rf_cls_pipeline,param_grid=param_grid,cv=5,n_jobs=-1,scoring='f1')
grid.fit(x_train,y_train)
print("Best Params are : ",grid.best_params_)
best_clf=grid.best_estimator_
y_pred_best=best_clf.predict(x_test)
print(classification_report(y_test,y_pred_best))
# Out:
# Best Params are :  {'rf_clf__max_depth': None, 'rf_clf__max_features': None, 'rf_clf__n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       329
#            1       0.99      0.99      0.99       525
#
#     accuracy                           0.99       854
#    macro avg       0.99      0.99      0.99       854
# weighted avg       0.99      0.99      0.99       854

# %%
rf_cls_pipeline=Pipeline(steps=[
    ('preprocess',preprocessor),
    ('rf_cls',RandomForestClassifier(n_estimators=400,max_depth=None,max_features=None,random_state=10))
])
rf_cls_pipeline.fit(x_train,y_train)
y_pred_cls=rf_cls_pipeline.predict(x_test)
print("classifction report is : \n",classification_report(y_pred_cls,y_test))
# Out:
# classifction report is :
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       327
#            1       0.99      0.99      0.99       527
#
#     accuracy                           0.99       854
#    macro avg       0.98      0.99      0.99       854
# weighted avg       0.99      0.99      0.99       854

# %%
rf_cls_pipeline
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['no_of_dependents',
#                                                    'income_annum',
#                                                    'loan_amount', 'loan_term',
#                                                    'cibil_score',
#                                                    'residential_assets_value',
#                                                    'commercial_assets_value',
#                                                    'luxury_assets_value',
# ...

# %%
important_features=rf_cls_pipeline.named_steps['rf_cls'].feature_importances_
important_features_preprocessor=rf_cls_pipeline.named_steps['preprocess']
important_features_names=important_features_preprocessor.get_feature_names_out()
important_features_df=pd.DataFrame({
    'features':important_features_names,
    'importance':important_features
})
important_features_df=important_features_df.sort_values(by='importance',ascending=False)
print("Important Features Names :\n",important_features_df)

plt.figure(figsize=(10,6))
plt.title("Importance of Features in Classification Problem")
plt.ylabel("Features Names")
plt.xlabel("Importance")
plt.barh(important_features_df['features'][:10],important_features_df['importance'][:10])
plt.show()
# Out:
# Important Features Names :
#                           features  importance
# 4                num__cibil_score    0.825571
# 3                  num__loan_term    0.082287
# 2                num__loan_amount    0.033595
# 1               num__income_annum    0.026460
# 7        num__luxury_assets_value    0.008486
# 6    num__commercial_assets_value    0.007485
# 5   num__residential_assets_value    0.006916
# 8           num__bank_asset_value    0.003861
# 0           num__no_of_dependents    0.003304
# 11         cat__self_employed_ No    0.000578
# 12        cat__self_employed_ Yes    0.000562
# 9        cat__education_ Graduate    0.000451
# 10   cat__education_ Not Graduate    0.000443

# %% [markdown]
# # Step 2 Regression

# %%
df['loan_status'].unique()
# Out:
# array([' Approved', ' Rejected'], dtype=object)

# %%
df['loan_status']=df['loan_status'].str.strip()

# %%
df['loan_status'].unique()
# Out:
# array(['Approved', 'Rejected'], dtype=object)

# %%
approved_df=df[df['loan_status']=='Approved'].copy()

# %%
approved_df.shape
# Out:
# (2656, 12)

# %%
approved_df.head()
# Out:
#     no_of_dependents  education self_employed  income_annum  loan_amount  \
# 0                  2   Graduate            No       9600000     29900000
# 6                  5   Graduate            No       8700000     33000000
# 8                  0   Graduate           Yes        800000      2200000
# 10                 4   Graduate           Yes       2900000     11200000
# 13                 2   Graduate           Yes       9100000     31500000
#
#     loan_term  cibil_score  residential_assets_value  commercial_assets_value  \
# 0          12          778                   2400000                 17600000
# 6           4          678                  22500000                 14800000
# 8          20          782                   1300000                   800000
# 10          2          547                   8100000                  4700000
# 13         14          679                  10800000                 16600000
#
#     luxury_assets_value  bank_asset_value loan_status
# ...

# %%
reg_target='loan_amount'
red_df=approved_df.dropna(subset=[reg_target]).copy()

# %%
x_reg=approved_df.drop(columns=[reg_target])
y_reg=approved_df[reg_target]

# %%
cat_column_reg=x_reg.select_dtypes(include=['object','category']).columns.to_list()
num_column_reg=x_reg.select_dtypes(include=['number']).columns.to_list()

# %%
print("Categorical columns are : ",cat_column_reg)
print("Numerical Columns are : ",num_column_reg)
# Out:
# Categorical columns are :  ['education', 'self_employed', 'loan_status']
# Numerical Columns are :  ['no_of_dependents', 'income_annum', 'loan_term', 'cibil_score', 'residential_assets_value', 'commercial_assets_value', 'luxury_assets_value', 'bank_asset_value']

# %%
x_trainr,x_testr,y_trainr,y_testr=train_test_split(x_reg,y_reg,test_size=0.2,random_state=10)
print("shape of x train is : ",x_trainr.shape)
print("Shape of y train is : ",x_testr.shape)
# Out:
# shape of x train is :  (2124, 11)
# Shape of y train is :  (532, 11)

# %%
reg_preprocessor=ColumnTransformer(transformers=[
                    ('num',numeric_transformer,num_column_reg ),
                    ('cat',categorical_transformer,cat_column_reg)              
                                   ],remainder='drop')

# %%
rf_reg_pipeline=Pipeline(steps=[
    ('preprocess',reg_preprocessor),
    ('rf_reg',RandomForestRegressor())
]
)

# %%
param_reg_grid = {
    'rf_reg__n_estimators' : [100,200,300,400],
    'rf_reg__max_depth' : [None, 4, 8, 10],
    'rf_reg__max_features' : ['sqrt', None],
    'rf_reg__min_samples_split' : [2,5,10]
}

# %%
grid=GridSearchCV(rf_reg_pipeline,param_reg_grid,cv=5,n_jobs=-1)
grid.fit(x_trainr,y_trainr)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['no_of_dependents',
#                                                                           'income_annum',
#                                                                           'loan_term',
#                                                                           'cibil_score',
# ...

# %%
print("Best parameters are :",grid.best_params_)
best_reg=grid.best_estimator_
# Out:
# Best parameters are : {'rf_reg__max_depth': 4, 'rf_reg__max_features': None, 'rf_reg__min_samples_split': 5, 'rf_reg__n_estimators': 400}

# %%
grid.best_score_
# Out:
# np.float64(0.8697383239923946)

# %%
ref_reg_pipeline=Pipeline(steps=[
    ('preprocess',reg_preprocessor),
    ('rf_reg',RandomForestRegressor(
        max_depth=8,
        max_features=None,
        min_samples_split=5,
        n_estimators=500,
        random_state=10
    ))
])
ref_reg_pipeline.fit(x_trainr,y_trainr)
yr_test_pred=ref_reg_pipeline.predict(x_testr)
print("mean squared error r is :",mean_squared_error(y_testr,yr_test_pred))
print("mean absloute error r is :",mean_absolute_error(y_testr,yr_test_pred))
print("r2 score is : ",r2_score(y_testr,yr_test_pred))
# Out:
# mean squared error r is : 11103582645894.693
# mean absloute error r is : 2506843.018871719
# r2 score is :  0.86550660669553

# %%
importantr_features=ref_reg_pipeline.named_steps['rf_reg'].feature_importances_
importantr_features_preprocessor=ref_reg_pipeline.named_steps['preprocess']
importantr_features_names=importantr_features_preprocessor.get_feature_names_out()
importantr_features_names_df=pd.DataFrame({
    'featurer':importantr_features_names,
    'importancer':importantr_features
})
importantr_features_names_df=importantr_features_names_df.sort_values(by='importancer',ascending=False)

print("top 10 Features are : \n",importantr_features_names_df)

plt.figure(figsize=(15,5))
plt.title("Importance of features in regression broblem")
plt.ylabel("Features")
plt.xlabel("Their Importance")
plt.barh(importantr_features_names_df['featurer'][:10],importantr_features_names_df['importancer'][:10])
plt.show()
# Out:
# top 10 Features are :
#                           featurer  importancer
# 1               num__income_annum     0.933608
# 3                num__cibil_score     0.014388
# 6        num__luxury_assets_value     0.011092
# 4   num__residential_assets_value     0.011032
# 5    num__commercial_assets_value     0.009790
# 7           num__bank_asset_value     0.008867
# 2                  num__loan_term     0.005826
# 0           num__no_of_dependents     0.003664
# 10         cat__self_employed_ No     0.000498
# 11        cat__self_employed_ Yes     0.000469
# 9    cat__education_ Not Graduate     0.000396
# 8        cat__education_ Graduate     0.000372
# 12      cat__loan_status_Approved     0.000000

# %%
joblib.dump(rf_cls_pipeline,"stage1_classification.pkl")
joblib.dump(rf_reg_pipeline,"stage2_regression.pkl")
# Out:
# ['stage2_regression.pkl']

# %%
clf=joblib.load('./stage1_classification.pkl')
reg=joblib.load('./stage2_regression.pkl')
